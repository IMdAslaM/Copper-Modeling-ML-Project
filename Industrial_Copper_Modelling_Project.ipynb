# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl (16.3 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# import pygwalker as pyg
df = pd.read_csv(r"C:/Users/2142866/GUVI_Project/Copper_Set.csv")
df
# Out:
# C:\Users\2142866\AppData\Local\Temp\ipykernel_6076\3183369089.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:/Users/2142866/GUVI_Project/Copper_Set.csv")
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# ...

# %%
# Out:
# -1160.0

# %%
print(df.shape)
# Out:
# (181673, 14)

# %%
df.describe()
# Out:
#           item_date      customer        country    application  \
# count  1.816720e+05  1.816720e+05  181645.000000  181649.000000
# mean   2.020459e+07  3.051221e+07      44.893022      25.615809
# std    4.551119e+03  2.433382e+07      24.404214      17.754175
# min    1.995000e+07  1.245800e+04      25.000000       2.000000
# 25%    2.020093e+07  3.019688e+07      26.000000      10.000000
# 50%    2.020113e+07  3.020524e+07      30.000000      15.000000
# 75%    2.021020e+07  3.028042e+07      78.000000      41.000000
# max    2.021040e+07  2.147484e+09     113.000000      99.000000
#
#            thickness          width   product_ref  delivery date  \
# count  181672.000000  181673.000000  1.816730e+05   1.816720e+05
# mean        2.564827    1295.286724  4.739679e+08   2.020738e+07
# std         6.572321     261.631754  7.175101e+08   2.411059e+04
# min         0.180000       1.000000  6.117280e+05   2.019040e+07
# ...

# %%
df.isna().sum() #it will give a sum of NAN(NULL) values in df
# Out:
# id                   2
# item_date            1
# quantity tons        0
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        1
# selling_price        1
# dtype: int64

# %%
# dropping material_ref column since it has more null values and it looks not important
new_df=df.drop("material_ref",axis=1)
new_df=new_df.drop("id",axis=1)
new_df.isna().sum()
# Out:
# item_date         1
# quantity tons     0
# customer          1
# country          28
# status            2
# item type         0
# application      24
# thickness         1
# width             0
# product_ref       0
# delivery date     1
# selling_price     1
# dtype: int64

# %%
new_df=new_df.dropna() #dropping Null values since we have only one Null value
new_df.isna().sum()
# Out:
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
print(new_df.shape)
# Out:
# (181636, 13)

# %%
# Out:
# (181635, 13)

# %%
20212222.0

# %%
new_df['delivery date'].unique()
# Out:
# array([20210701., 20210401., 20210101., 20210301., 20210601., 20210501.,
#        20210801., 20210901., 20211001., 20211101., 20220101., 20200701.,
#        20201001., 20210201., 20190701., 20200801., 20201101., 20201201.,
#        20190401., 20200101., 20200601., 20200401., 20200901., 20200501.,
#        20212222., 20211201.])

# %%
new_df['item_date'].isin([20191919.0]).value_counts()
# Out:
# item_date
# False    181635
# True          1
# Name: count, dtype: int64

# %%
new_df['item_date'].isin([20210401.0]).value_counts()
# Out:
# item_date
# False    180978
# True        658
# Name: count, dtype: int64

# %%
20210401.0

# %% [markdown]
# #Data Preprocessing - Handling Outliers

# %%
#Checking IQR for each column to detect outliers
#IQR using Numpy
import numpy as np
import matplotlib.pyplot as plt
d1=new_df['product_ref']
Q1 = np.percentile(d1, 25)
# Third quartile (Q3)
Q3 = np.percentile(d1, 75)
# Interquaritle range (IQR)
IQR = Q3 - Q1
print(IQR)
plt.boxplot(d1)
plt.show()
# Out:
# 1331465144.0

# %%
#Replacing Outlier value in thickness column using IQR
data=new_df['thickness']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
#print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# print(lower_bound)
# print(upper_bound)
new_df['thickness']=data.clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(new_df['thickness'])
plt.show()

# %%
#Replacing Outlier value in width column using IQR
data=new_df['width']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
#print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# print(lower_bound)
# print(upper_bound)
new_df['width']=data.clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(new_df['width'])
plt.show()

# %%
#Replacing Outlier value in application column using IQR
data=new_df['application']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
#print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# print(lower_bound)
# print(upper_bound)
new_df['application']=data.clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(new_df['application'])
plt.show()

# %%
#Replacing Outlier value in customer column using IQR
data=new_df['customer']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
#print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# print(lower_bound)
# print(upper_bound)
new_df['customer']=data.clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(new_df['customer'])
plt.show()

# %%
#Replacing Outlier value in item_date column using IQR
data=new_df['item_date']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
#print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# print(lower_bound)
# print(upper_bound)
new_df['item_date']=data.clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(new_df['item_date'])
plt.show()

# %%
#Replacing Outlier value in selling_price column using IQR
data=new_df['selling_price']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
#print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(lower_bound)
print(upper_bound)
new_df['selling_price']=data.clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(new_df['selling_price'])
plt.show()
# Out:
# 243.0
# 1379.0

# %%
#Replacing Outlier value in selling_price column using IQR
data=new_df['delivery date']
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1
#print(IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(lower_bound)
print(upper_bound)
new_df['delivery date']=data.clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(new_df['delivery date'])
plt.show()
# Out:
# 20187151.0
# 20224351.0

# %%
new_df[new_df['selling_price']<0]
# Out:
# Empty DataFrame
# Columns: [id, item_date, quantity tons, customer, country, status, item type, application, thickness, width, product_ref, delivery date, selling_price]
# Index: []

# %%
c=new_df['quantity tons']=='e'
c.value_counts()
# Out:
# quantity tons
# False    181635
# True          1
# Name: count, dtype: int64

# %%
c=new_df[new_df['diff_date']<0]   #.value_counts() #.drop('Revised',axis=0)

c
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
c=new_df[new_df['quantity tons'].astype(float)<=0]   #.value_counts() #.drop('Revised',axis=0)
c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-227-ae2dda3f96cb> in <cell line: 1>()
# ----> 1 c=new_df[new_df['quantity tons'].astype(float)<=0]   #.value_counts() #.drop('Revised',axis=0)
#       2 c
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6322         else:
#    6323             # else, only a single dtype is given
# -> 6324             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325             return self._constructor(new_data).__finalize__(self, method="astype")
#    6326
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     449             copy = False
#     450
# --> 451         return self.apply(
#     452             "astype",
#     453             dtype=dtype,
#
# ...

# %%
print(new_df['selling_price'].astype(float).min())
new_df['selling_price'].astype(float).max()
# Out:
# 0.1
# 100001015.0

# %%
print(new_df['quantity tons'].astype(float).min())
new_df['quantity tons'].astype(float).max()
# Out:
# 0.100526528
# 70252.36307

# %%
new_df['quantity tons'].unique()
# Out:
# array([ 54.15113862, 768.0248392 , 386.1279489 , ..., 208.0864686 ,
#          4.23559357, 406.6865384 ])

# %%
#calculating mean of the 'selling_price' column excluding values <0 (-ve values)
mean_selling_price=new_df[new_df['selling_price'] >=0]['selling_price'].mean()
print(mean_selling_price)
#replacing values <0 (-ve values) with mean of the 'selling_price' column in  'selling_price' column
new_df['selling_price']=new_df['selling_price'].apply(lambda x: mean_selling_price if x <=0 else x)
#new_df.loc[new_df['selling_price'] <0, 'selling_price'] = mean_selling_price
# Out:
# 819.1155087591803

# %%
#filtering the 'quantity tons' column where value is 'e' because we are having one categorical value e in 'quantity tons' column
c=new_df[new_df['quantity tons'].isin([0.2000565583])]   #.value_counts() #.drop('Revised',axis=0)

c
# Out:
#                                          id   item_date  quantity tons  \
# 72001  62BA191B-2325-4744-97B6-786E17C06A56  20201222.0       0.200057
#
#          customer  country status item type  application  thickness   width  \
# 72001  30299962.0     28.0    Won        PL         10.0        1.5  1500.0
#
#        product_ref  delivery date  selling_price
# 72001    164141591     20210301.0          716.5

# %%
c=new_df[new_df['quantity tons']<0.1]
c
# Out:
#                                           id   item_date  quantity tons  \
# 1077    F5E0D0A8-1A3D-4899-8E3B-6715779BFA46  20210331.0       0.091587
# 2764    CAEC31E0-CC28-4A79-BFDF-DAD1C0758174  20210329.0       0.058714
# 4665    1053A907-FE80-4C39-8BC6-21B78C6F3252  20210325.0       0.021473
# 5327    3251FD07-E817-4188-AD8D-8CCBB582AA51  20210324.0       0.045524
# 5521    30E89BCA-EBF5-49F7-A8D4-2B1CE50B41AA  20210324.0       0.063895
# ...                                      ...         ...            ...
# 176919  1CD54DC8-E84E-4204-8631-206E7E9077E1  20200708.0       0.099455
# 177068  4485AAA6-B6FF-4466-9B9B-21D0CE87313A  20200708.0       0.011255
# 181096  1FB62B9D-51DA-4D54-A13F-807571079275  20200702.0       0.085359
# 181288  57C13ED0-6EA3-4245-AFCF-B4E83849598E  20200702.0       0.076611
# 181583  7B11B895-37DB-4B4D-AFE0-6E90D4A28C67  20200702.0       0.097044
#
#           customer  country           status item type  application  \
# ...

# %%
print(new_df['quantity tons'].astype(float).min())
new_df['quantity tons'].astype(float).max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-cd2b1e3a8bfc> in <cell line: 1>()
# ----> 1 print(new_df['quantity tons'].astype(float).min())
#       2 new_df['quantity tons'].astype(float).max()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6322         else:
#    6323             # else, only a single dtype is given
# -> 6324             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325             return self._constructor(new_data).__finalize__(self, method="astype")
#    6326
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     449             copy = False
#     450
# --> 451         return self.apply(
#     452             "astype",
#     453             dtype=dtype,
#
# ...

# %%
new_df['diff_date'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#calculating mean of the 'quantity tons' column excluding 'e'
median_quantity_tons=new_df.loc[new_df['quantity tons'] != 'e', 'quantity tons'].astype(float).median()
print(median_quantity_tons)

#replacing 'e' with mean of the 'quantity tons' column in  'quantity tons' column
new_df.loc[new_df['quantity tons'] == 'e', 'quantity tons'] = median_quantity_tons
new_df['quantity tons']=new_df['quantity tons'].astype(float)

new_df['quantity tons']=new_df['quantity tons'].apply(lambda x: median_quantity_tons if x <0.1 else x)
# Out:
# 30.36257954

# %%
new_df['quantity tons'].unique()
# Out:
# array([ 54.15113862, 768.0248392 , 386.1279489 , ..., 208.0864686 ,
#          4.23559357, 406.6865384 ])

# %%
#Removing all other categories in status column except Won and Lost
categories_to_keep=['Won','Lost']
new_df=new_df[new_df['status'].isin(categories_to_keep)]
new_df
0	20210401.0	54.151139	30156308.0	28.0	1	5	10.0	2.00	1500.0	1670798778	20210701.0	854.00	2021-04-01	2021	4	1
1	20210401.0	768.024839	30202938.0	25.0	1	5	41.0	0.80	1210.0	1668701718	20210401.0	1047.00	2021-04-01	2021	4	1
2	20210401.0	386.127949	30153963.0	30.0	1	6	28.0	0.38	952.0	628377	20210101.0	644.33	2021-04-01	2021	4	1
3	20210401.0	202.411065	30349574.0	32.0	1	3	59.0	2.30	1317.0	1668701718	20210101.0	768.00	2021-04-01	2021	4	1
4	20210401.0	785.526262	30211560.0	28.0	1	5	10.0	4.00	1980.0	640665	20210301.0	577.00	2021-04-01	2021	4	1
# Out:
#          item_date  quantity tons    customer  country status item type  \
# 0       20210401.0      54.151139  30156308.0     28.0    Won         W
# 1       20210401.0     768.024839  30202938.0     25.0    Won         W
# 2       20210401.0     386.127949  30153963.0     30.0    Won        WI
# 3       20210401.0     202.411065  30349574.0     32.0    Won         S
# 4       20210401.0     785.526262  30211560.0     28.0    Won         W
# ...            ...            ...         ...      ...    ...       ...
# 181668  20200702.0     102.482422  30200854.0     25.0    Won         W
# 181669  20200702.0     208.086469  30200854.0     25.0    Won         W
# 181670  20200702.0       4.235594  30200854.0     25.0    Won         W
# 181671  20200702.0      30.362580  30200854.0     25.0    Won         W
# 181672  20200702.0     406.686538  30200854.0     25.0    Won         W
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
# import pickle
# from sklearn.preprocessing import LabelEncoder

# new_df['item_type_encoder'] = encoder.fit(new_df['item type'])
# new_df['status_encoder'] = encoder.fit(new_df['status'])

# %%
# #Saving the encoder
# with open('encoder.pkl', 'wb') as f:
#     pickle.dump(encoder, f)

# %%
# #load the encoder
# with open('encoder.pkl', 'rb') as f:
#     loaded_encoder = pickle.load(f)

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.5.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# ...
#   Using cached scipy-1.14.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.5.1-cp312-cp312-win_amd64.whl (10.9 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached scipy-1.14.0-cp312-cp312-win_amd64.whl (44.5 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#converting categorical values to numerical values using label encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
new_df['item type'] = encoder.fit_transform(new_df['item type'])
new_df['status'] = encoder.fit_transform(new_df['status'])

# %%
mapping={'Won':1,'Lost':0}
new_df['status']=

# %%
new_df.dtypes
# Out:
# item_date        float64
# quantity tons    float64
# customer         float64
# country          float64
# status             int64
# item type          int64
# application      float64
# thickness        float64
# width            float64
# product_ref        int64
# delivery date    float64
# selling_price    float64
# dtype: object

# %%
new_df['diffdate']=(new_df['delivery date']-new_df['item_date']).abs()
c=new_df[new_df['diffdate']<0]
c
# Out:
# Empty DataFrame
# Columns: [item_date, quantity tons, customer, country, status, item type, application, thickness, width, product_ref, delivery date, selling_price, item_year, item_month, item_day, delivery_year, delivery_month, diffdate]
# Index: []

# %%
drop=[20187018.0,20191919.0,19950000]
new_df=new_df[~new_df['item_date'].isin(drop)]
print(new_df.shape)
# Out:
# (150438, 12)

# %%
c = (new_df["diffdate"] < 0).sum()
print(c)
# Out:
# 14656

# %%
df_filtered_neg = new_df[new_df["diffdate"] < 0]
# df_filtered.reset_index(drop=True, inplace=True)
df_filtered_neg['diffdate'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diffdate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
new_df['c_item_date']=pd.to_datetime(new_df['item_date'],format='%Y%m%d')
# new_df['delivery date']=pd.to_datetime(new_df['delivery date'])
new_df['c_item_date']
# Out:
# C:\Users\2142866\AppData\Local\Temp\ipykernel_6076\511479653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['c_item_date']=pd.to_datetime(new_df['item_date'],format='%Y%m%d')
# 0        2021-04-01
# 1        2021-04-01
# 2        2021-04-01
# 3        2021-04-01
# 4        2021-04-01
#             ...
# 181668   2020-07-02
# 181669   2020-07-02
# 181670   2020-07-02
# 181671   2020-07-02
# 181672   2020-07-02
# Name: c_item_date, Length: 150438, dtype: datetime64[ns]

# %%
new_df['item_year']=new_df['c_item_date'].dt.year
new_df['item_month']=new_df['c_item_date'].dt.month
new_df['item_day']=new_df['c_item_date'].dt.day
new_df
# Out:
# C:\Users\2142866\AppData\Local\Temp\ipykernel_6076\1513720884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['item_year']=new_df['c_item_date'].dt.year
# C:\Users\2142866\AppData\Local\Temp\ipykernel_6076\1513720884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['item_month']=new_df['c_item_date'].dt.month
# C:\Users\2142866\AppData\Local\Temp\ipykernel_6076\1513720884.py:3: SettingWithCopyWarning:
# ...

# %%
# 20212222.0
drop=[20212222.0]
new_df=new_df[~new_df['delivery date'].isin(drop)]
print(new_df.shape)
# Out:
# (150437, 16)

# %%
import pandas as pd
new_df['c_delivery_date']=pd.to_datetime(new_df['delivery date'],format='%Y%m%d')
# new_df['delivery date']=pd.to_datetime(new_df['delivery date'])

new_df['c_delivery_date']
# Out:
# 0        2021-07-01
# 1        2021-04-01
# 2        2021-01-01
# 3        2021-01-01
# 4        2021-03-01
#             ...
# 181668   2020-07-01
# 181669   2020-07-01
# 181670   2020-07-01
# 181671   2020-07-01
# 181672   2020-07-01
# Name: c_delivery_date, Length: 150437, dtype: datetime64[ns]

# %%
new_df['delivery_year']=new_df['c_delivery_date'].dt.year
new_df['delivery_month']=new_df['c_delivery_date'].dt.month
#new_df['delivery_day']=new_df['c_delivery_date'].dt.day
new_df
# Out:
#          item_date  quantity tons    customer  country  status  item type  \
# 0       20210401.0      54.151139  30156308.0     28.0       1          5
# 1       20210401.0     768.024839  30202938.0     25.0       1          5
# 2       20210401.0     386.127949  30153963.0     30.0       1          6
# 3       20210401.0     202.411065  30349574.0     32.0       1          3
# 4       20210401.0     785.526262  30211560.0     28.0       1          5
# ...            ...            ...         ...      ...     ...        ...
# 181668  20200702.0     102.482422  30200854.0     25.0       1          5
# 181669  20200702.0     208.086469  30200854.0     25.0       1          5
# 181670  20200702.0       4.235594  30200854.0     25.0       1          5
# 181671  20200702.0      30.362580  30200854.0     25.0       1          5
# 181672  20200702.0     406.686538  30200854.0     25.0       1          5
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
new_df['diffdate']=(new_df['c_delivery_date']-new_df['c_item_date']).abs()
new_df['diffdate']=new_df['diffdate']/pd.Timedelta(days=1)
#new_df['diffdate']=new_df['diffdate'].dt.days
# new_df['diffdate_gt0']=new_df['diffdate']>=0
# new_df['diffdate_gt0']

# %%
new_df=new_df.drop("c_item_date",axis=1)
new_df=new_df.drop("c_delivery_date",axis=1)

# %%
new_df=new_df.drop("delivery_day",axis=1)

# %%
new_df['delivery_day'].value_counts()
# Out:
# delivery_day
# 1    150437
# Name: count, dtype: int64

# %%
new_df.dtypes
# Out:
# item_date         float64
# quantity tons     float64
# customer          float64
# country           float64
# status              int64
# item type           int64
# application       float64
# thickness         float64
# width             float64
# product_ref         int64
# delivery date     float64
# selling_price     float64
# item_year           int32
# item_month          int32
# item_day            int32
# delivery_year       int32
# delivery_month      int32
# diffdate          float64
# dtype: object

# %%
new_df=new_df.drop("diffdate_gt0",axis=1)
new_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-91268a848c0d> in <cell line: 1>()
# ----> 1 new_df=new_df.drop("diffdate_gt0",axis=1)
#       2 new_df.dtypes
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
print(new_df['item_year'].astype(float).min())
new_df['item_year'].astype(float).max()
# Out:
# 2020.0
# np.float64(2021.0)

# %%
new_df
# Out:
#          item_date  quantity tons    customer  country  status  item type  \
# 0       20210401.0       4.010077  30156308.0     28.0       1          5
# 1       20210401.0       6.645123  30202938.0     25.0       1          5
# 2       20210401.0       5.958755  30153963.0     30.0       1          6
# 3       20210401.0       5.315229  30349574.0     32.0       1          3
# 4       20210401.0       6.667626  30211560.0     28.0       1          5
# ...            ...            ...         ...      ...     ...        ...
# 181668  20200702.0       4.639402  30200854.0     25.0       1          5
# 181669  20200702.0       5.342748  30200854.0     25.0       1          5
# 181670  20200702.0       1.655480  30200854.0     25.0       1          5
# 181671  20200702.0       3.445615  30200854.0     25.0       1          5
# 181672  20200702.0       6.010499  30200854.0     25.0       1          5
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
#Detecting Skewness in each column
import pandas as pd
from scipy.stats import skew,boxcox
from scipy.special import boxcox1p
import numpy as np

Skewness_before = new_df.apply(lambda x: skew(x))
print(Skewness_before)

new_df['quantity tons']=np.log1p(new_df['quantity tons'])
#new_df['diffdate']=np.log1p(new_df['diffdate']) #don't do skewness for item type
#new_df['status']=np.log1p(new_df['status']) #don't do skewness for item type because i will affect classifier model
new_df['item_day']=np.log1p(new_df['item_day'])
#new_df['item type']=np.log1p(new_df['item type']) #don't do skewness for item type


Skewness_after = new_df.apply(lambda x: skew(x))
print("\n")
print("after")
print(Skewness_after)
# Out:
# item_date          0.457299
# quantity tons     53.809554
# customer           0.912757
# country            0.708351
# status            -1.290750
# item type         -0.619385
# application        0.734798
# thickness          1.025032
# width              0.650044
# product_ref        1.013413
# delivery date     -0.727886
# selling_price      0.456990
# item_year          0.459582
# item_month        -0.193209
# item_day           0.077034
# delivery_year     -0.732183
# delivery_month     0.133132
# diffdate           0.521922
# dtype: float64
#
#
# after
# item_date         0.457299
# quantity tons     0.365785
# customer          0.912757
# country           0.708351
# status           -1.290750
# item type        -0.619385
# application       0.734798
# thickness         1.025032
# width             0.650044
# product_ref       1.013413
# delivery date    -0.727886
# selling_price     0.456990
# item_year         0.459582
# item_month       -0.193209
# ...

# %%
Skewness_before = new_df.apply(lambda x: skew(x))
Skewness_before
# Out:
# item_date        0.457299
# quantity tons    0.365785
# customer         0.909711
# country          0.708351
# status          -1.290750
# item type       -0.619385
# application      0.734798
# thickness        1.025032
# width            0.650044
# product_ref      1.013413
# delivery date   -0.727886
# selling_price    0.456990
# dtype: float64

# %% [markdown]
# #EDA - Hypothesis Testing

# %%
#EDA Hypothesis testing

#Shapiro test is used to check whether the data is normally ditributed(Normal Curve) or not
#Here shapiro will take Normal Curve as Default
import scipy.stats as st
print("Sharpiro : ",st.shapiro(new_df["item_date"]))
#Since p value is less than alpha (5%) the distibution does not follow normality.
#p>0.05 the dataset is normal(cannot reject H0)
#p<0.05 the dataset is not normal(can reject H0)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-24-466cebf2493f> in <cell line: 6>()
#       4 #Here shapiro will take Normal Curve as Default
#       5 import scipy.stats as st
# ----> 6 print("Sharpiro : ",st.shapiro(new_df["item_date"]))
#       7 #Since p value is less than alpha (5%) the distibution does not follow normality.
#       8 #p>0.05 the dataset is normal(cannot reject H0)
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py in shapiro(x)
#    1869         raise ValueError("Data must be at least length 3.")
#    1870
# -> 1871     x = x - np.median(x)
#    1872
#    1873     a = zeros(N, 'f')
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3925
#    3926     """
# -> 3927     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
# ...

# %%
def check_normality(data):
    from scipy import stats
    test_stat_normality, p_value_normality=stats.shapiro(data)
    print("p value:%.4f" % p_value_normality)
    if p_value_normality <0.05:
        print("Reject null hypothesis >> The data is not normally distributed")
    else:
        print("Fail to reject null hypothesis >> The data is normally distributed")

# %%
def check_variance_homogeneity(group1, group2):
    from scipy import stats
    test_stat_var, p_value_var= stats.levene(group1,group2)
    print("p value:%.4f" % p_value_var)
    if p_value_var <0.05:
        print("Reject null hypothesis >> The variances of the samples are different.")
    else:
        print("Fail to reject null hypothesis >> The variances of the samples are same.")

# %%
new_df['quantity tons'].dtype
# Out:
# dtype('float64')

# %%
import numpy as np
# country is dependent with selling price
new_df['quantity tons']=new_df['quantity tons'].astype(float)
feature = new_df['delivery date']
target = new_df['selling_price']
check_normality(feature)
check_normality(target)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-423-e4b28b06169b> in <cell line: 6>()
#       4 feature = new_df['delivery date']
#       5 target = new_df['selling_price']
# ----> 6 check_normality(feature)
#       7 check_normality(target)
#
# <ipython-input-377-02d66f94f187> in check_normality(data)
#       1 def check_normality(data):
#       2     from scipy import stats
# ----> 3     test_stat_normality, p_value_normality=stats.shapiro(data)
#       4     print("p value:%.4f" % p_value_normality)
#       5     if p_value_normality <0.05:
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py in shapiro(x)
#    1869         raise ValueError("Data must be at least length 3.")
#    1870
# -> 1871     x = x - np.median(x)
#    1872
#    1873     a = zeros(N, 'f')
#
# ...

# %%
check_variance_homogeneity(feature, target)
# Out:
# p value:0.0000
# Reject null hypothesis >> The variances of the samples are different.

# %%
from scipy.stats import spearmanr
corr,pvalue = spearmanr(feature, target)
print("p-value:%.4f" % pvalue)
if pvalue <0.05:
    print("Reject null hypothesis, , pvalue <0.05")
else:
    print("Fail to reject null hypothesis, pvalue >0.05")
# Out:
# p-value:0.0000
# Reject null hypothesis, , pvalue <0.05

# %% [markdown]
# #Model Building

# %%
new_df
# Out:
#          item_date  quantity tons    customer  country  status  item type  \
# 0       20210401.0       4.010077  30156308.0     28.0       1          5
# 1       20210401.0       6.645123  30202938.0     25.0       1          5
# 2       20210401.0       5.958755  30153963.0     30.0       1          6
# 3       20210401.0       5.315229  30349574.0     32.0       1          3
# 4       20210401.0       6.667626  30211560.0     28.0       1          5
# ...            ...            ...         ...      ...     ...        ...
# 181668  20200702.0       4.639402  30200854.0     25.0       1          5
# 181669  20200702.0       5.342748  30200854.0     25.0       1          5
# 181670  20200702.0       1.655480  30200854.0     25.0       1          5
# 181671  20200702.0       3.445615  30200854.0     25.0       1          5
# 181672  20200702.0       6.010499  30200854.0     25.0       1          5
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
# X = new_df.drop(['selling_price'], axis=1)
# 'customer',
#,'delivery date'
import numpy as np
X = new_df[['quantity tons','customer','country','status','item type','application','thickness','width','product_ref','item_year','item_month','item_day','delivery_year','delivery_month','diffdate']].values
#X = np.asarray(feature_df)
y = new_df['selling_price'].values

# %%
X = new_df[['quantity tons','customer','country','status','item type','application','thickness','width','product_ref','item_year','item_month','item_day','delivery_year','delivery_month','diffdate']]
X
31,30341432.0,77,1,3,41,1,1000,611993,2020,11,4,2020,7,1
# Out:
#         quantity tons    customer  country  status  item type  application  \
# 0            4.010077  30156308.0     28.0       1          5         10.0
# 1            6.645123  30202938.0     25.0       1          5         41.0
# 2            5.958755  30153963.0     30.0       1          6         28.0
# 3            5.315229  30349574.0     32.0       1          3         59.0
# 4            6.667626  30211560.0     28.0       1          5         10.0
# ...               ...         ...      ...     ...        ...          ...
# 181668       4.639402  30200854.0     25.0       1          5         41.0
# 181669       5.342748  30200854.0     25.0       1          5         41.0
# 181670       1.655480  30200854.0     25.0       1          5         41.0
# 181671       3.445615  30200854.0     25.0       1          5         41.0
# 181672       6.010499  30200854.0     25.0       1          5         41.0
#
# ...

# %%
new_df['quantity tons'].astype(float).max()

# %%
print(new_df['quantity tons'].astype(float).min())
new_df['quantity tons'].astype(float).max()
# Out:
# 0.09578872710048202
# 11.159863458932685

# %%
df=pd.DataFrame(X)
df
31,30341432.0,77,1,3,41,1,1000,611993,20201203
# Out:
#               0           1     2    3    4     5     6       7   \
# 0       4.010077  30156308.0  28.0  1.0  5.0  10.0  2.00  1500.0
# 1       6.645123  30202938.0  25.0  1.0  5.0  41.0  0.80  1210.0
# 2       5.958755  30153963.0  30.0  1.0  6.0  28.0  0.38   952.0
# 3       5.315229  30349574.0  32.0  1.0  3.0  59.0  2.30  1317.0
# 4       6.667626  30211560.0  28.0  1.0  5.0  10.0  4.00  1980.0
# ...          ...         ...   ...  ...  ...   ...   ...     ...
# 150432  4.639402  30200854.0  25.0  1.0  5.0  41.0  0.96  1220.0
# 150433  5.342748  30200854.0  25.0  1.0  5.0  41.0  0.95  1500.0
# 150434  1.655480  30200854.0  25.0  1.0  5.0  41.0  0.71  1250.0
# 150435  3.445615  30200854.0  25.0  1.0  5.0  41.0  0.85  1250.0
# 150436  6.010499  30200854.0  25.0  1.0  5.0  41.0  0.71  1240.0
#
#                   8       9    10        11      12   13    14
# 0       1.670799e+09  2021.0  4.0  0.693147  2021.0  7.0  91.0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, KFold
#from sklearn.datasets import load_boston

model=LinearRegression()

kfold=KFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(model,X,y,cv=kfold)
print(scores)
print(scores.mean())
# Out:
# [0.62178257 0.60924505 0.61762245 0.61915249 0.60764372 0.61564153
#  0.61154442 0.61070814 0.60951291 0.61543461]
# 0.6138287886046064

# %%
# splittin train and test
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train
# Out:
# array([[-0.85724425,  0.06411355, -1.11575178, ..., -1.18294782,
#         -0.65853283, -1.48588359],
#        [ 1.27676385, -0.13948241,  1.70060772, ...,  2.68805568,
#         -0.65849314,  0.79366824],
#        [-0.85191755, -0.0983593 , -1.00657848, ...,  0.83155401,
#          1.67477719, -1.48588359],
#        ...,
#        [-0.83416189, -0.0900487 ,  0.94648534, ..., -0.19544692,
#         -0.65853283, -1.39560431],
#        [-0.85724425,  0.17985514, -1.00939939, ..., -1.18294782,
#         -0.65850994, -1.46331377],
#        [-0.81263316,  0.02441207, -0.99091613, ...,  0.39705361,
#         -0.4300762 , -1.41817413]])

# %%
X_test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-169-aa79807fd330> in <cell line: 1>()
# ----> 1 X_test.head(1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
#pipeline edhuku use pandromna neraya opearations ah pipeline kullaye panna mudiyum adhanaala
#inga scaling use pandrom
#Scaling edhukuna ella features oda values um oralavukku same ah irukanum. but inga paathomna income values 6 digit layum age values two digiots layum iruku. ipdi irundha model correct ah predict pannadhu adhanaala dhaan scaling use pandrom
#Motive of the scaling in machine learning is to rebalance the weightage of features or overfitting issues of final model
#Usually we will do scaling after splitting the data, because if we do scaling after splitting we will get new max and new min value which will be ood for model training
#applying scaling after splitting the data

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline


pipeline = Pipeline([
('std_scalar', StandardScaler())
])


X_train = pipeline.fit_transform(X_train)
X_test = pipeline.fit_transform(X_test)
X_test
# Out:
# array([[ 2.24994049, -0.36130159, -0.54690878, ..., -1.43322627,
#          1.25039352,  0.07164672],
#        [ 0.56656659, -0.41561999, -0.71022675, ...,  0.69721622,
#         -0.49925518,  0.21845424],
#        [ 1.66185077, -0.44191532, -0.79188573, ..., -1.43322627,
#          1.25039352, -1.20068512],
#        ...,
#        [-1.77294881, -0.15577098,  1.3312479 , ..., -1.43322627,
#          1.25039352, -1.32302472],
#        [ 0.00771721,  1.52374504,  1.29041841, ..., -1.43322627,
#          1.25039352, -0.83366632],
#        [ 1.00883827, -1.11592986, -0.62856776, ..., -1.43322627,
#          0.37556917, -1.37196056]])

# %% [markdown]
# #Linear Regression to predict Selling Price

# %%
#traing the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 825.6798558445939
# [ -7.76485706  -7.99701508 -10.55104985  17.26544459  16.34185886
#  -78.21730221  -0.49075202  -7.03691621]

# %%
min(new_df['item_date'])
# Out:
# 20187018.0

# %%
#'item_date','quantity tons','customer','country','status','item type','application', 'thickness', 'width','product_ref','delivery date'
y_pred = model.predict(X_test)
y_preds
# Out:
# array([644.95300552, 721.6502937 , 639.79794009, ..., 825.14075804,
#        770.21257722, 698.01922399])

# %%
y_pred = model.predict(pipeline.fit_transform([[31,30341432.0,77,1,3,41,1,1000,611993,2020,11,4,2020,7,1]]))
y_pred=round(int(y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y_pred = model.predict(pipeline.fit_transform([[31,30341432.0,77,1,3,41,1,1000,611993,2020,11,4,2020,7,1]]))
#       2 y_pred
#
# NameError: name 'model' is not defined

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#         Actual   Predicted
# 0       562.00  644.953006
# 1       816.00  721.650294
# 2       554.00  639.797940
# 3       712.00  747.300497
# 4       568.00  711.825760
# ...        ...         ...
# 49640   749.00  779.188665
# 49641   751.00  835.359519
# 49642   976.00  825.140758
# 49643  1379.00  770.212577
# 49644   701.46  698.019224
#
# [49645 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 55284286665.029564
# Mean Squared Error: 4.535623526784426e+21
# Root Mean Squared Error: 67347037995.62699

# %%
score = model.score(X_test,y_test)
print(score)
print(score * 100,"%")
# Out:
# 0.6135305119055225
# 61.35305119055226 %

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.6135305119055225

# %% [markdown]
# #Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)
rf_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred=rf_reg.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#          Actual  Predicted
# 164803   562.00   749.2400
# 56937    816.00  1004.6096
# 122851   554.00   736.4650
# 112007   712.00   727.6900
# 163828   568.00   853.8263
# ...         ...        ...
# 94849    749.00   749.0600
# 64231    751.00   884.7298
# 138835   976.00   991.9882
# 150363  1379.00   878.0388
# 178521   701.46   868.2998
#
# [49645 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 112.968951110908
# Mean Squared Error: 24993.99045429488
# Root Mean Squared Error: 158.09487801410543

# %%
score = rf_reg.score(X_test,y_test)
print(score)
print(score * 100,"%")
# Out:
# 0.33154914543086966
# 33.15491454308697 %

# %% [markdown]
# #XGBoost Regressor

# %%
import xgboost as xgb
xgb_reg=xgb.XGBRegressor()
xgb_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb_reg.predict(X_test)

# %%
score = xgb_reg.score(X_test,y_test)
print(score)
print(score * 100,"%")
# Out:
# -0.39763852952540946
# -39.763852952540944 %

# %% [markdown]
# #ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
model_ExtratreeReg=ExtraTreesRegressor(n_estimators=150,random_state=42)
model_ExtratreeReg.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor(n_estimators=150, random_state=42)

# %%
y_pred=model_ExtratreeReg.predict(X_test)

# %%
y_pred = model_ExtratreeReg.predict(pipeline.fit_transform([[31,30341432.0,77,1,3,41,1,1000,611993,2020,11,4,2020,7,1]]))
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y_pred = model_ExtratreeReg.predict(pipeline.fit_transform([[31,30341432.0,77,1,3,41,1,1000,611993,2020,11,4,2020,7,1]]))
#       2 y_pred
#
# NameError: name 'model_ExtratreeReg' is not defined

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.7805442881215274

# %%
#pickle edhukuna oru dhadava train panna model ah store panni, theva padumbodhu innoru dhadava use pandradhuku
#below code is to store the model to files
import pickle
with open("knowlege_pkl_ExtratreeReg","wb") as files:
  pickle.dump(model_ExtratreeReg, files)

# %%
#below code is to access the stored model from files
import pickle
with open("knowlege_pkl_ExtratreeReg","rb") as files:
  model_ExtratreeReg=pickle.load(files)

# %% [markdown]
# #Classification Models

# %% [markdown]
# ##Logistic Reression

# %%
# [['quantity tons','customer','country','status','item type','application','thickness','width','product_ref','item_year','item_month','item_day','delivery_year','delivery_month','diffdate'
new_df['status'].value_counts()
# Out:
# status
# 1    116006
# 0     34431
# Name: count, dtype: int64

# %%
# X = new_df.drop(['selling_price'], axis=1)
# 'customer',
#,'delivery date'
import numpy as np
X = new_df[['quantity tons','customer','country','item type','application','thickness', 'width','product_ref','item_year','item_month','item_day','delivery_year','delivery_month','diffdate','selling_price']]
#X = np.asarray(feature_df)
y = new_df['status']

# %%
# splittin train and test
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
#handling imbalanced data
# !pip install imbalanced-learn
# Out:
# ...
#    ---------------------------------------- 0.0/258.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/258.3 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/258.3 kB 495.5 kB/s eta 0:00:01
#    ---------------------------------------  256.0/258.3 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 258.3/258.3 kB 1.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#handling imbalanced data
import pandas as pd
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

#before sampling
print(y_train.value_counts())
# Out:
# status
# 1    78004
# 0    22788
# Name: count, dtype: int64

# %%
#Applying both oversampling and undersampling to handle imbalanced data
over = SMOTE(sampling_strategy=0.65)
X_train,y_train=over.fit_resample(X_train,y_train)

print('over',y_train.value_counts())


under = RandomUnderSampler(sampling_strategy='majority')
X_train,y_train=under.fit_resample(X_train,y_train)

print('under',y_train.value_counts())


#define pipeline
# pipeline = Pipeline(steps=[('o', over), ('u', under)])

# # #transform the dataset
# X, y = pipeline.fit_resample(X_res,y_res)

# #after sampling
print(X_train.shape)
print(y_train.shape)
# Out:
# over status
# 1    78004
# 0    50702
# Name: count, dtype: int64
# under status
# 0    50702
# 1    50702
# Name: count, dtype: int64
# (101404, 15)
# (101404,)

# %%
#pipeline edhuku use pandromna neraya opearations ah pipeline kullaye panna mudiyum adhanaala
#inga scaling use pandrom
#Scaling edhukuna ella features oda values um oralavukku same ah irukanum. but inga paathomna income values 6 digit layum age values two digiots layum iruku. ipdi irundha model correct ah predict pannadhu adhanaala dhaan scaling use pandrom
#Motive of the scaling in machine learning is to rebalance the weightage of features or overfitting issues of final model
#Usually we will do scaling after splitting the data, because if we do scaling after splitting we will get new max and new min value which will be ood for model training
#applying scaling after splitting the data

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline


pipeline = Pipeline([
('std_scalar', StandardScaler())
])


X_train = pipeline.fit_transform(X_train)
X_test = pipeline.fit_transform(X_test)
X_test
# Out:
# array([[ 2.24994049, -0.36130159, -0.54690878, ...,  1.25039352,
#          0.07164672, -1.341547  ],
#        [ 0.56656659, -0.41561999, -0.71022675, ..., -0.49925518,
#          0.21845424, -0.03899997],
#        [ 1.66185077, -0.44191532, -0.79188573, ...,  1.25039352,
#         -1.20068512, -1.3825721 ],
#        ...,
#        [-1.77294881, -0.15577098,  1.3312479 , ...,  1.25039352,
#         -1.32302472,  0.78150209],
#        [ 0.00771721,  1.52374504,  1.29041841, ...,  1.25039352,
#         -0.83366632,  2.84814167],
#        [ 1.00883827, -1.11592986, -0.62856776, ...,  0.37556917,
#         -1.37196056, -0.62637689]])

# %%
from sklearn.linear_model import LogisticRegression


model_logistic = LogisticRegression() #using LogisticRegression() function
model_logistic.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
score = model_logistic.score(X_test,y_test)
print(score)
print(score * 100,"%")
# Out:
# 0.6584550307180985
# 65.84550307180986 %

# %%
y_predict= model_logistic.predict(X_test)
y_predict
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
y_pred = model_logistic.predict(pipeline.fit_transform([[20210512.0,99,30153344.0,28,4,41,1,1000,614444,20210719.0,890]]))
y_pred
# Out:
# array([1])

# %%
y_predict_th22 = np.where(model_logistic.predict_proba(pipeline.fit_transform([[31,30341432.0,77,3,41,1,1000,611993,2020,11,4,2020,7,1,890]]))[:,1]>0.2,1,0)
y_predict_th22
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 y_predict_th22 = np.where(model_logistic.predict_proba(pipeline.fit_transform([[20210512.0,99,30153344.0,28,4,41,1,1000,614444,20210719.0,890]]))[:,1]>0.2,1,0)
#       2 y_predict_th22
#
# File c:\Users\2142866\GUVI_Project\nenv\Lib\site-packages\sklearn\linear_model\_logistic.py:1431, in LogisticRegression.predict_proba(self, X)
#    1423 ovr = self.multi_class in ["ovr", "warn"] or (
#    1424     self.multi_class in ["auto", "deprecated"]
#    1425     and (
#    (...)
#    1428     )
#    1429 )
#    1430 if ovr:
# -> 1431     return super()._predict_proba_lr(X)
#    1432 else:
#    1433     decision = self.decision_function(X)
#
# File c:\Users\2142866\GUVI_Project\nenv\Lib\site-packages\sklearn\linear_model\_base.py:397, in LinearClassifierMixin._predict_proba_lr(self, X)
# ...

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict_th2))

pd.crosstab(y_test,y_predict_th2)
# Out:
# 0.7980461275052876
# col_0      0      1
# status
# 0       5081   6562
# 1       3464  34538

# %%
from sklearn.metrics import classification_report
print (classification_report(y_test, y_predict_th2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.43      0.50     11643
#            1       0.84      0.91      0.87     38002
#
#     accuracy                           0.80     49645
#    macro avg       0.72      0.67      0.69     49645
# weighted avg       0.78      0.80      0.79     49645

# %%
import numpy as np
#mela Output la namaku 6 value thappa prdict aachi, so adha vandhu different threshold value koduthu (0.3 or 0.4) error ah kammi panna try pandrom
y_predict_th2 = np.where(model_logistic.predict_proba(X_test)[:,1]>0.2,1,0) # Threshold is 0.3 #np.where na if condition maari explanation: Xtest feature's threshold >0.3 na 1 set aagiddum and less than 0.3 na 0 nu set aagidum
y_predict_th4 = np.where(model_logistic.predict_proba(X_test)[:,1]>0.4,1,0) # Threshold is 0.4

# %%
#pickle edhukuna oru dhadava train panna model ah store panni, theva padumbodhu innoru dhadava use pandradhuku
#below code is to store the model to files
import pickle
with open("knowlege_pkl_LogisticReg","wb") as files:
  pickle.dump(model_logistic, files)

# %%
pd.crosstab(y_test,y_predict_th2)
# Out:
# col_0       1
# status
# 0       11523
# 1       38121

# %% [markdown]
# #Random Forest Classifier

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

# %%
from sklearn.ensemble import RandomForestClassifier


# instantiate the classifier
#rfc = RandomForestClassifier(n_estimators=10,random_state=0)
rfc = RandomForestClassifier(n_estimators=10, random_state=42)#random estimators = 100 na 100 decision trees

# fit the model
rfc.fit(X_train, y_train)




# Predict the Test set results
y_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score


print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.8077

# %% [markdown]
# #XGBoost Classifier

# %%
import xgboost as xgb
model_xgb=xgb.XGBClassifier()
model_xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=model_xgb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.35747809447074225

# %%
import streamlit as st
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
import time
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
import pickle


def page_home():
    st.title("Welcome to My Streamlit Dashboard")

    st.markdown('## Problem Statement of this ML application:')
    st.markdown('The copper industry deals with less complex data related to sales and pricing. However, this data may suffer from issues such as skewness and noisy data, which can affect the accuracy of manual predictions. Dealing with these challenges manually can be time-consuming and may not result in optimal pricing decisions. A machine learning regression model can address these issues by utilizing advanced techniques such as data normalization, feature scaling, and outlier detection, and leveraging algorithms that are robust to skewed and noisy data.')
    st.markdown('Another area where the copper industry faces challenges is in capturing the leads. A lead classification model is a system for evaluating and classifying leads based on how likely they are to become a customer . You can use the STATUS variable with WON being considered as Success and LOST being considered as Failure and remove data points other than WON, LOST STATUS values.')


def page_price():
    item_date_pred=st.text_input('Enter item_date Example: 20200702 i.e. YYYYMMDD')#getting a input from User
    quantity_tons_pred=st.text_input('Enter quantity_tons')
    customer_pred=st.text_input('Enter CustomerId')#getting a input from User
    country_pred=st.text_input('Enter Country')
    status_pred=st.text_input('Enter status')
    item_type_pred=st.text_input('Enter item_type')
    application_pred=st.text_input('Enter application')
    thickness_pred=st.text_input('Enter thickness')
    width_pred=st.text_input('Enter width')
    product_ref_pred=st.text_input('Enter product_ref')
    delivery_date_pred=st.text_input('Enter delivery_date')

    with open('knowlege_pkl_ExtratreeReg', 'rb') as file:
        model_ExtratreeReg=pickle.load(file)

    if st.button('Predict Selling Price'):#button
                placeholder=st.empty()
                p=pd.DataFrame([item_date_pred,quantity_tons_pred,customer_pred,country_pred,status_pred,item_type_pred,application_pred,thickness_pred,width_pred,product_ref_pred,delivery_date_pred])
                p=p.astype(float)
                pipeline = Pipeline([
                ('std_scalar', StandardScaler())])
                y_pred = model_ExtratreeReg.predict(pipeline.fit_transform([[float(item_date_pred),float(quantity_tons_pred),float(customer_pred),float(country_pred),float(status_pred),float(item_type_pred),float(application_pred),float(thickness_pred),float(width_pred),float(product_ref_pred),float(delivery_date_pred)]]))
                #st.write('Data is migrating to MongoDB🚀...')
                st.write("Predicted Selling Price",y_pred)
                time.sleep(30)


def page_status():
    pass


def main():
    st.sidebar.title("Page Navigation👇")
    selection = st.sidebar.selectbox("",["Home Page 🏠", "Predict Selling Price", "Predict Status"])

    if selection == "Home Page 🏠":
        page_home()
    elif selection == "Predict Selling Price":
        page_price()
    elif selection == "Predict Status":
        page_status()

if __name__=="__main__":
    main()
